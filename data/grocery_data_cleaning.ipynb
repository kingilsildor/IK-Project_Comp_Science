# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/groceries/groceries - groceries.csv
# /kaggle/input/groceries/groceries.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/groceries/groceries - groceries.csv', index_col=False)

# %%
df.head()
# Out:
#    Item(s)            Item 1               Item 2          Item 3  \
# 0        4      citrus fruit  semi-finished bread       margarine
# 1        3    tropical fruit               yogurt          coffee
# 2        1        whole milk                  NaN             NaN
# 3        4         pip fruit               yogurt    cream cheese
# 4        4  other vegetables           whole milk  condensed milk
#
#                      Item 4 Item 5 Item 6 Item 7 Item 8 Item 9  ... Item 23  \
# 0               ready soups    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 1                       NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 2                       NaN    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 3              meat spreads    NaN    NaN    NaN    NaN    NaN  ...     NaN
# 4  long life bakery product    NaN    NaN    NaN    NaN    NaN  ...     NaN
#
#   Item 24 Item 25 Item 26 Item 27 Item 28 Item 29 Item 30 Item 31 Item 32
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9835 entries, 0 to 9834
# Data columns (total 33 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Item(s)  9835 non-null   int64
#  1   Item 1   9835 non-null   object
#  2   Item 2   7676 non-null   object
#  3   Item 3   6033 non-null   object
#  4   Item 4   4734 non-null   object
#  5   Item 5   3729 non-null   object
#  6   Item 6   2874 non-null   object
#  7   Item 7   2229 non-null   object
#  8   Item 8   1684 non-null   object
#  9   Item 9   1246 non-null   object
#  10  Item 10  896 non-null    object
#  11  Item 11  650 non-null    object
#  12  Item 12  468 non-null    object
#  13  Item 13  351 non-null    object
#  14  Item 14  273 non-null    object
#  15  Item 15  196 non-null    object
#  16  Item 16  141 non-null    object
#  17  Item 17  95 non-null     object
#  18  Item 18  66 non-null     object
#  19  Item 19  52 non-null     object
# ...

# %%
len(list(df.stack().unique()))
list(df.stack().unique())
# Out:
# [4,
#  'citrus fruit',
#  'semi-finished bread',
#  'margarine',
#  'ready soups',
#  3,
#  'tropical fruit',
#  'yogurt',
#  'coffee',
#  1,
#  'whole milk',
#  'pip fruit',
#  'cream cheese',
#  'meat spreads',
#  'other vegetables',
#  'condensed milk',
#  'long life bakery product',
#  5,
#  'butter',
#  'rice',
#  'abrasive cleaner',
#  'rolls/buns',
#  'UHT-milk',
#  'bottled beer',
#  'liquor (appetizer)',
#  'potted plants',
#  2,
#  'cereals',
#  'white bread',
#  'bottled water',
#  'chocolate',
#  9,
#  'curd',
#  'flour',
#  'dishes',
#  'beef',
#  'frankfurter',
#  'soda',
#  'chicken',
#  'sugar',
#  'fruit/vegetable juice',
#  'newspapers',
#  'packaged fruit/vegetables',
#  'specialty bar',
#  'butter milk',
#  'pastry',
#  'processed cheese',
#  'detergent',
#  11,
#  'root vegetables',
#  'frozen dessert',
#  'sweet spreads',
#  'salty snack',
#  'waffles',
#  'candy',
#  'bathroom cleaner',
#  'canned beer',
#  'sausage',
#  6,
#  'brown bread',
# ...

# %%
len(list(df['Item 1'].unique()))
# Out:
# 158

# %%
categories = {
    'broodafdeling': ['semi-finished bread', 'rolls/buns', 'brown bread', 'white bread', 'zwieback', 'baguette'],
    'verse_broodjes': ['pastry', 'waffles'],
    'salade_kaas': ['cream cheese', 'curd', 'whipped/sour cream', 'spread cheese', 'hard cheese', 'soft cheese'],
    'kaas_en_tapas': ['processed cheese', 'sliced cheese', 'specialty cheese'],
    'vega_vis_halal_vleeswaren': ['vegetarian products', 'fish', 'sausage', 'ham', 'turkey', 'beef', 'pork', 'chicken', 'meat'],
    'silvo_sausen_azijn_olie_ei': ['condiments', 'sauces', 'vinegar', 'oil', 'mayonnaise', 'mustard'],
    'soep_bakproducten': ['ready soups', 'bouillon', 'soup vegetables', 'canned soup', 'soup powder'],
    'cereals_broodbeleg': ['cereals', 'muesli', 'bread spreads', 'honey', 'jam', 'chocolate spread'],
    'koek_koffie': ['cookies', 'biscuits', 'crackers', 'coffee', 'instant coffee'],
    'houdbareZuivel_suiker_koffiemelk_thee': ['long life bakery product', 'UHT-milk', 'bottled water', 'sugar', 'coffee creamer', 'tea'],
    'nootjes_zoutjes_chips': ['nuts', 'prunes', 'crisps', 'popcorn', 'pretzels', 'snack mix'],
    'toetjes_boter': ['pudding', 'dessert', 'ice cream', 'butter', 'margarine'],
    'melk_zuivel': ['whole milk', 'butter milk', 'buttermilk drinks'],
    'sappen': ['fruit/vegetable juice', 'juice', 'smoothies'],
    'frisdrank': ['soda', 'cola', 'lemonade', 'soft drinks'],
    'luiers_baby': ['baby diapers', 'baby wipes', 'baby food'],
    'frisdrank_wasmiddel_huishouden': ['soda', 'soft drinks', 'laundry detergent', 'household cleaning products'],
    'reinigers_bleek_dierenvoeding': ['cleaning agents', 'bleach', 'pet food'],
    'cosmetica_papierwaren': ['cosmetics', 'skin care', 'toiletries', 'tissues', 'toilet paper'],
    'bier': ['bottled beer', 'canned beer'],
    'groente_fruit': ['fresh vegetables', 'fresh fruit'],
    'gesnedenGroenten_maaltijden_sappen': ['packaged vegetables', 'packaged fruit', 'ready meals', 'smoothies'],
    'aardappelen': ['potatoes'],
    'rijst': ['rice', 'risotto'],
    'oosters': ['Asian food', 'rice noodles', 'soy sauce', 'curry paste'],
    'diepvries': ['frozen vegetables', 'frozen fruit', 'frozen fish', 'frozen chicken', 'frozen meals', 'ice cream'],
    'wijn': ['red wine', 'white wine', 'sparkling wine', 'prosecco'],
    'speciaalBier': ['specialty beer', 'craft beer']
}

# %%
print(categories)

# df.replace(categories, inplace=True)
# Out:
# {'broodafdeling': ['semi-finished bread', 'rolls/buns', 'brown bread', 'white bread', 'zwieback', 'baguette'], 'verse_broodjes': ['pastry', 'waffles'], 'salade_kaas': ['cream cheese', 'curd', 'whipped/sour cream', 'spread cheese', 'hard cheese', 'soft cheese'], 'kaas_en_tapas': ['processed cheese', 'sliced cheese', 'specialty cheese'], 'vega_vis_halal_vleeswaren': ['vegetarian products', 'fish', 'sausage', 'ham', 'turkey', 'beef', 'pork', 'chicken', 'meat'], 'silvo_sausen_azijn_olie_ei': ['condiments', 'sauces', 'vinegar', 'oil', 'mayonnaise', 'mustard'], 'soep_bakproducten': ['ready soups', 'bouillon', 'soup vegetables', 'canned soup', 'soup powder'], 'cereals_broodbeleg': ['cereals', 'muesli', 'bread spreads', 'honey', 'jam', 'chocolate spread'], 'koek_koffie': ['cookies', 'biscuits', 'crackers', 'coffee', 'instant coffee'], 'houdbareZuivel_suiker_koffiemelk_thee': ['long life bakery product', 'UHT-milk', 'bottled water', 'sugar', 'coffee creamer', 'tea'], 'nootjes_zoutjes_chips': 
# ...

# %%
def reverse_dictionary(original_dict):
    reversed_dict = {}

    for key, value_list in original_dict.items():
        for item in value_list:
            reversed_dict[item] = key

    return reversed_dict

rev_categories = reverse_dictionary(categories)

# %%
# df.pop(df.columns[0])
df.pop('Item(s)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/conda/lib/python3.10/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Item(s)'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df = df.astype(str)

# %%
df_categories = df.replace(rev_categories)

# %%
df_categories
# Out:
#                          Item 1                                 Item 2  \
# 0                  citrus fruit                          broodafdeling
# 1                tropical fruit                                 yogurt
# 2                   melk_zuivel                                    nan
# 3                     pip fruit                                 yogurt
# 4              other vegetables                            melk_zuivel
# ...                         ...                                    ...
# 9830  vega_vis_halal_vleeswaren              vega_vis_halal_vleeswaren
# 9831          cooking chocolate                                    nan
# 9832  vega_vis_halal_vleeswaren                           citrus fruit
# 9833              broodafdeling  houdbareZuivel_suiker_koffiemelk_thee
# 9834  vega_vis_halal_vleeswaren                         tropical fruit
#
#                               Item 3                                 Item 4  \
# ...

# %%
df_categories.info
# Out:
# <bound method DataFrame.info of                          Item 1                                 Item 2  \
# 0                  citrus fruit                          broodafdeling
# 1                tropical fruit                                 yogurt
# 2                   melk_zuivel                                    nan
# 3                     pip fruit                                 yogurt
# 4              other vegetables                            melk_zuivel
# ...                         ...                                    ...
# 9830  vega_vis_halal_vleeswaren              vega_vis_halal_vleeswaren
# 9831          cooking chocolate                                    nan
# 9832  vega_vis_halal_vleeswaren                           citrus fruit
# 9833              broodafdeling  houdbareZuivel_suiker_koffiemelk_thee
# 9834  vega_vis_halal_vleeswaren                         tropical fruit
#
#                               Item 3                                 Item 4  \
# ...

# %%
# List of allowed values
allowed_values = list(categories.keys())

# Filtering DataFrame
filtered_df = df2[df2.apply(lambda row: all(value in allowed_values or pd.isna(value) for value in row), axis=1)]

print(list(filtered_df.stack().unique()))
# Out:
# ['groente_fruit', 'houdbareZuivel_suiker_koffiemelk_thee', 'toetjes_boter', 'rijst', 'frisdrank_wasmiddel_huishouden', 'broodafdeling', 'melk_zuivel', 'bier', 'wijn', 'cereals_broodbeleg', 'koek_koffie', 'sappen', 'gesnedenGroenten_maaltijden_sappen', 'speciaalBier', 'verse_broodjes', 'vega_vis_halal_vleeswaren', 'diepvries', 'salade_kaas', 'reinigers_bleek_dierenvoeding', 'oosters', 'cosmetica_papierwaren', 'nootjes_zoutjes_chips', 'silvo_sausen_azijn_olie_ei', 'kaas_en_tapas', 'aardappelen']

# %%
filtered_df
# Out:
#                                      Item 1  \
# 1                             groente_fruit
# 2     houdbareZuivel_suiker_koffiemelk_thee
# 5     houdbareZuivel_suiker_koffiemelk_thee
# 6                             broodafdeling
# 7                             groente_fruit
# ...                                     ...
# 9816              vega_vis_halal_vleeswaren
# 9821                          groente_fruit
# 9822  houdbareZuivel_suiker_koffiemelk_thee
# 9823              vega_vis_halal_vleeswaren
# 9833                          broodafdeling
#
#                                      Item 2  \
# 1     houdbareZuivel_suiker_koffiemelk_thee
# 2                                       NaN
# 5                             toetjes_boter
# 6                                       NaN
# 7                               melk_zuivel
# ...                                     ...
# 9816                          groente_fruit
# 9821                          groente_fruit
# ...

# %%
filtered_df.to_csv("groceries_basket_categorized.csv")
